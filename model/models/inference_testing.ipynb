# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %cd "/content/drive/MyDrive/MNLP - Projet/project-m3-2024-nnnandanders/model"
# %pip install -r requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from huggingface_hub import login

hf_token = "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"
login(token=hf_token)

# %%
# !python evaluator.py
